# %%
import os
import math
import numpy as np
import healpy as hp
from astropy.io import fits as pyfits
import matplotlib.pyplot as plt

# %%
cut_0_2 = "outfiler_N256_02.fits"
readmap = hp.read_map(cut_0_2)
nside = 8

# %%
view = hp.mollview(readmap)

# %%
cut_0_5 = "outfiler_N256_05.fits"
readmap = hp.read_map(cut_0_5)
nside = 8

# %%
view = hp.mollview(readmap)

# %%
cut_0_8 = "outfiler_N256_08.fits"
readmap = hp.read_map(cut_0_8)
nside = 8

# %%
view = hp.mollview(readmap)
